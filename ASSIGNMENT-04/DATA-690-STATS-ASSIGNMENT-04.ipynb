# %%
import pandas as pd

# %%
data = pd.read_csv("MERGED2017_18_PP.csv")
# Out:
# /Users/harshithayentrapragada/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (1729) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.head()
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 0     AL       35762           NaN      NaN     NaN  ...
# 1     AL  35294-0110           NaN      NaN     NaN  ...
# 2     AL  36117-3553           NaN      NaN     NaN  ...
# 3     AL       35899           NaN      NaN     NaN  ...
# 4     AL  36104-0271           NaN      NaN     NaN  ...
#
#    OMENRUP_PARTTIME_POOLED_SUPP  FTFTPCTPELL  FTFTPCTFLOAN   UG12MN   G12MN  \
# 0                           NaN       0.7106        0.7418   5207.0  1185.0
# ...

# %% [markdown]
# ### 6 Question

# %% [markdown]
# #### How many colleges?

# %%
data["INSTNM"].nunique()
# Out:
# 6974

# %% [markdown]
# #### How many rows?

# %%
len(data)
# Out:
# 7112

# %% [markdown]
# #### how many variables or columns?

# %%
n = len(data.columns)
print(n)
# Out:
# 1986

# %% [markdown]
# #### Look at the first 5 colleges

# %%
data.head(5)
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 0     AL       35762           NaN      NaN     NaN  ...
# 1     AL  35294-0110           NaN      NaN     NaN  ...
# 2     AL  36117-3553           NaN      NaN     NaN  ...
# 3     AL       35899           NaN      NaN     NaN  ...
# 4     AL  36104-0271           NaN      NaN     NaN  ...
#
#    OMENRUP_PARTTIME_POOLED_SUPP  FTFTPCTPELL  FTFTPCTFLOAN   UG12MN   G12MN  \
# 0                           NaN       0.7106        0.7418   5207.0  1185.0
# ...

# %% [markdown]
# #### look at the last 5 colleges

# %%
data.tail(5)
# Out:
#         UNITID    OPEID  OPEID6  \
# 7107  48312404   108163    1081
# 7108  48387801  4223701   42237
# 7109  48400201  4228101   42281
# 7110  48778201  4221501   42215
# 7111  49005401  4182601   41826
#
#                                                  INSTNM             CITY  \
# 7107                   Arizona State University at Yuma             Yuma
# 7108  Bay Area Medical Academy - San Jose Satellite ...         San Jose
# 7109           High Desert Medical College - Bakerfield      Bakersfield
# 7110                                       BCI - Malden           Malden
# 7111               HCI College - Fort Lauderdale Campus  Fort Lauderdale
#
#      STABBR        ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 7107     AZ  853656900           NaN      NaN     NaN  ...
# 7108     CA      95113           NaN      NaN     NaN  ...
# 7109     CA      93301           NaN      NaN     NaN  ...
# 7110     MA  021480000           NaN      NaN     NaN  ...
# ...

# %% [markdown]
# #### Look at a random sample of 5 colleges

# %%
print(data["INSTNM"].sample(n = 6, replace = "True"))
# Out:
# 4923                       Texas County Technical College
# 5940                       Los Angeles Pacific University
# 61                         University of Alaska Fairbanks
# 1559    Hellenic College-Holy Cross Greek Orthodox Sch...
# 3563                                   Trinity University
# 915                      Paul Mitchell the School-Bradley
# Name: INSTNM, dtype: object

# %% [markdown]
# ### 7. Since there are too many variables to explore, many of which are not interesting. Create a smaller data frame with the following 9 variables:

# %%
new_data = data[["UNITID","INSTNM","CITY","STABBR","ZIP","ADM_RATE","UGDS","TUITIONFEE_IN","MN_EARN_WNE_P10"]]
new_data.shape
# Out:
# (7112, 9)

# %%
new_data.head(7)
# Out:
#    UNITID                               INSTNM            CITY STABBR  \
# 0  100654             Alabama A & M University          Normal     AL
# 1  100663  University of Alabama at Birmingham      Birmingham     AL
# 2  100690                   Amridge University      Montgomery     AL
# 3  100706  University of Alabama in Huntsville      Huntsville     AL
# 4  100724             Alabama State University      Montgomery     AL
# 5  100751            The University of Alabama      Tuscaloosa     AL
# 6  100760    Central Alabama Community College  Alexander City     AL
#
#           ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 0       35762    0.9027   4824.0         9857.0              NaN
# 1  35294-0110    0.9181  12866.0         8328.0              NaN
# 2  36117-3553       NaN    318.0         6900.0              NaN
# 3       35899    0.8123   6917.0        10280.0              NaN
# 4  36104-0271    0.9787   4189.0        11068.0              NaN
# ...

# %% [markdown]
# ### 8 & 9. Find out the definition of the above 9 variables and document the definitions in the Jupyter Notebook in a Markdown cell so that the readers of your notebook will know the meaning of these variables.

# %% [markdown]
# 1. UNITID:          ID of the university
# 2. INSTNM:          Name of the institution
# 3. CITY:            The city where the institution is located
# 4. STABBR:          Abbreviation of the state where the institution is located
# 5. ZIP:             The zipcode where the institution located
# 6. ADM_RATE:        Percentage of applicants that are admitted in to the institution
# 7. UGDS:            Total undergraduate enrollment
# 8. TUITIONFEE_IN:   Tution Fee
# 9. MN_EARN_WNE_P10: Institutional level 10 year earnings data

# %% [markdown]
# ### 10. Explore the smaller data frame

# %% [markdown]
# #### Look at the first 10 colleges

# %%
new_data.head(10)
# Out:
#    UNITID                               INSTNM            CITY STABBR  \
# 0  100654             Alabama A & M University          Normal     AL
# 1  100663  University of Alabama at Birmingham      Birmingham     AL
# 2  100690                   Amridge University      Montgomery     AL
# 3  100706  University of Alabama in Huntsville      Huntsville     AL
# 4  100724             Alabama State University      Montgomery     AL
# 5  100751            The University of Alabama      Tuscaloosa     AL
# 6  100760    Central Alabama Community College  Alexander City     AL
# 7  100812              Athens State University          Athens     AL
# 8  100830      Auburn University at Montgomery      Montgomery     AL
# 9  100858                    Auburn University          Auburn     AL
#
#           ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 0       35762    0.9027   4824.0         9857.0              NaN
# 1  35294-0110    0.9181  12866.0         8328.0              NaN
# ...

# %% [markdown]
# #### look at the last 10 colleges

# %%
new_data.tail(10)
# Out:
#         UNITID                                             INSTNM  \
# 7102  48154401  National Personal Training Institute of Cleveland
# 7103  48305401             Barber School of Pittsburgh - Ambridge
# 7104  48312401                 Arizona State University at Tucson
# 7105  48312402  Arizona State University - ASU Colleges at Lak...
# 7106  48312403        Arizona State University at The Gila Valley
# 7107  48312404                   Arizona State University at Yuma
# 7108  48387801  Bay Area Medical Academy - San Jose Satellite ...
# 7109  48400201           High Desert Medical College - Bakerfield
# 7110  48778201                                       BCI - Malden
# 7111  49005401               HCI College - Fort Lauderdale Campus
#
#                   CITY STABBR        ZIP  ADM_RATE  UGDS  TUITIONFEE_IN  \
# 7102  Highland Heights     OH      44143       NaN   NaN            NaN
# 7103          Ambridge     PA  150030000       NaN   NaN            NaN
# ...

# %% [markdown]
# #### Look at a random sample of 10 colleges

# %%
print(new_data["INSTNM"].sample(n = 10, replace = "True"))
# Out:
# 4093      Raphael's School of Beauty Culture Inc-Alliance
# 1197                     Mercy College of Health Sciences
# 3591              Paul Mitchell the School-Salt Lake City
# 2361                           Onondaga Community College
# 1019                            National Louis University
# 3296       Tennessee College of Applied Technology-Athens
# 5134    Eastern School of Acupuncture and Traditional ...
# 1592                    New England School of Photography
# 2726                          Miami University-Middletown
# 1861                        Aquinas Institute of Theology
# Name: INSTNM, dtype: object

# %% [markdown]
# #### Find and display UMBC

# %%
if 'University of Maryland-Baltimore County' in new_data['INSTNM'].values:
    print("\n Institution exists in DataFrame")
# Out:
#  Institution exists in DataFrame

# %%
new_data[new_data["INSTNM"] == "University of Maryland-Baltimore County"]
# Out:
#       UNITID                                   INSTNM       CITY STABBR  \
# 1478  163268  University of Maryland-Baltimore County  Baltimore     MD
#
#         ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1478  21250    0.6021  11130.0        11518.0              NaN

# %%
data["INSTNM"].unique()
# Out:
# array(['Alabama A & M University', 'University of Alabama at Birmingham',
#        'Amridge University', ...,
#        'High Desert Medical College - Bakerfield', 'BCI - Malden',
#        'HCI College - Fort Lauderdale Campus'], dtype=object)

# %% [markdown]
# #### Found the university based upon the city

# %%
if 'College Park' in new_data['CITY'].values:
    print("\n Institution exists in DataFrame")
# Out:
#  Institution exists in DataFrame

# %%
new_data[new_data["CITY"] == "College Park"]
# Out:
#       UNITID                               INSTNM          CITY STABBR    ZIP  \
# 1479  163286  University of Maryland-College Park  College Park     MD  20742
#
#       ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1479     0.445  29273.0        10399.0              NaN

# %% [markdown]
# #### Find and display Loyola College Maryland

# %%
new_data[new_data["CITY"] == "Baltimore"]
# Out:
#         UNITID                                   INSTNM       CITY STABBR  \
# 1451    161855          Baltimore Studio of Hair Design  Baltimore     MD
# 1452    161864         Baltimore City Community College  Baltimore     MD
# 1453    161873                  University of Baltimore  Baltimore     MD
# 1460    162283                  Coppin State University  Baltimore     MD
# 1462    162371             North American Trade Schools  Baltimore     MD
# 1466    162654                          Goucher College  Baltimore     MD
# 1473    162928                 Johns Hopkins University  Baltimore     MD
# 1475    163046               Loyola University Maryland  Baltimore     MD
# 1477    163259         University of Maryland Baltimore  Baltimore     MD
# 1478    163268  University of Maryland-Baltimore County  Baltimore     MD
# 1480    163295        Maryland Institute College of Art  Baltimore     MD
# 1485    163453                  Morgan State University  Baltimore     MD
# ...

# %%
new_data[new_data["ZIP"] == "21210-2699"]
# Out:
#       UNITID                      INSTNM       CITY STABBR         ZIP  \
# 1475  163046  Loyola University Maryland  Baltimore     MD  21210-2699
#
#       ADM_RATE    UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1475    0.7528  3903.0        47560.0              NaN

# %% [markdown]
# #### Find and display Johns Hopskins

# %%
new_data[new_data["CITY"] == "Baltimore"]
# Out:
#         UNITID                                   INSTNM       CITY STABBR  \
# 1451    161855          Baltimore Studio of Hair Design  Baltimore     MD
# 1452    161864         Baltimore City Community College  Baltimore     MD
# 1453    161873                  University of Baltimore  Baltimore     MD
# 1460    162283                  Coppin State University  Baltimore     MD
# 1462    162371             North American Trade Schools  Baltimore     MD
# 1466    162654                          Goucher College  Baltimore     MD
# 1473    162928                 Johns Hopkins University  Baltimore     MD
# 1475    163046               Loyola University Maryland  Baltimore     MD
# 1477    163259         University of Maryland Baltimore  Baltimore     MD
# 1478    163268  University of Maryland-Baltimore County  Baltimore     MD
# 1480    163295        Maryland Institute College of Art  Baltimore     MD
# 1485    163453                  Morgan State University  Baltimore     MD
# ...

# %%
new_data[new_data["ZIP"] == "21218-2688"]
# Out:
#       UNITID                    INSTNM       CITY STABBR         ZIP  \
# 1473  162928  Johns Hopkins University  Baltimore     MD  21218-2688
#
#       ADM_RATE    UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1473    0.1254  5663.0        52170.0              NaN

# %% [markdown]
# ### Calculate the min, max, and average in-state tution of the above four institutions
# 1. University of Maryland-Baltimore County
# 2. University of Maryland-College Park
# 3. Loyola University Maryland
# 4. Johns Hopkins University

# %%
Colleges = ["Johns Hopkins University", "Loyola University Maryland", "University of Maryland-College Park", "University of Maryland-Baltimore County"]

# %%
df1 = new_data[new_data["INSTNM"].isin(Colleges)]

# %%
df1
# Out:
#       UNITID                                   INSTNM          CITY STABBR  \
# 1473  162928                 Johns Hopkins University     Baltimore     MD
# 1475  163046               Loyola University Maryland     Baltimore     MD
# 1478  163268  University of Maryland-Baltimore County     Baltimore     MD
# 1479  163286      University of Maryland-College Park  College Park     MD
#
#              ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1473  21218-2688    0.1254   5663.0        52170.0              NaN
# 1475  21210-2699    0.7528   3903.0        47560.0              NaN
# 1478       21250    0.6021  11130.0        11518.0              NaN
# 1479       20742    0.4450  29273.0        10399.0              NaN

# %%
df1.describe()
# Out:
#               UNITID  ADM_RATE          UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# count       4.000000  4.000000      4.000000       4.000000              0.0
# mean   163132.000000  0.481325  12492.250000   30411.750000              NaN
# std       174.378898  0.268507  11602.631408   22546.011271              NaN
# min    162928.000000  0.125400   3903.000000   10399.000000              NaN
# 25%    163016.500000  0.365100   5223.000000   11238.250000              NaN
# 50%    163157.000000  0.523550   8396.500000   29539.000000              NaN
# 75%    163272.500000  0.639775  15665.750000   48712.500000              NaN
# max    163286.000000  0.752800  29273.000000   52170.000000              NaN

# %%
df1["TUITIONFEE_IN"].min()
# Out:
# 10399.0

# %%
df1["TUITIONFEE_IN"].max()
# Out:
# 52170.0

# %%
df1["TUITIONFEE_IN"].mean()
# Out:
# 30411.75

# %%
df1["TUITIONFEE_IN"].describe()
# Out:
# count        4.000000
# mean     30411.750000
# std      22546.011271
# min      10399.000000
# 25%      11238.250000
# 50%      29539.000000
# 75%      48712.500000
# max      52170.000000
# Name: TUITIONFEE_IN, dtype: float64

# %% [markdown]
# ### 11. Filter the smaller dataset further to only keep colleges from Maryland, Virgina, Washington DC, Delaware, and Pennsylvinia. Save the filtered dataset to a new file named "Five_States_Colleges.csv" for future analysis. Upload this file to your GitHub along with the notebook.

# %%
States_Colleges = ["MD","VA","DC","DE","PA"]

# %%
df2 = new_data[new_data["STABBR"].isin(States_Colleges)]

# %%
df2["STABBR"].unique()
# Out:
# array(['DE', 'DC', 'MD', 'PA', 'VA'], dtype=object)

# %%
Five_States_Colleges = df2.copy()

# %% [markdown]
# ### The final data saved to "Five_States_Colleges"

# %%
Five_States_Colleges.head()
# Out:
#      UNITID                                             INSTNM    CITY STABBR  \
# 634  130837  Margaret H Rollins School of Nursing at Beebe ...   Lewes     DE
# 635  130873                          Dawn Career Institute LLC  Newark     DE
# 636  130907         Delaware Technical Community College-Terry   Dover     DE
# 637  130934                          Delaware State University   Dover     DE
# 638  130943                             University of Delaware  Newark     DE
#
#        ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 634  19958       NaN     59.0            NaN              NaN
# 635  19702       NaN    108.0            NaN              NaN
# 636  19901       NaN  12408.0         4848.0              NaN
# 637  19901    0.4518   3678.0         7868.0              NaN
# 638  19716    0.6289  18948.0        13160.0              NaN
